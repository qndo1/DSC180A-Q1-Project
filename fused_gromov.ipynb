# %%
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
from pathlib import Path
import ot
import scipy as sp
import matplotlib.pyplot as plt
import utils
import accuracy

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import random

random.seed(10)

lcp = utils.LoadCloudPoint(filepath="datasets/csv_files/0005_Jogging001.csv")
source_pc, target_pc = lcp.get_two_random_point_cloud()

dp = utils.DistanceProfile(source_pc, target_pc)
distance_matrix = dp.compute_L2_matrix()

# %%
M = ot.dist(source_pc, target_pc)

# %%
G = ot.fused_gromov_wasserstein(M, distance_matrix[0], distance_matrix[1])

# %%
utils.plot_3d_points_and_connections(source_pc, target_pc, G, color_incorrect=True)

# %%
accs = []
alphas = np.arange(0, 1, 0.01)
for alpha in alphas:
    G = ot.fused_gromov_wasserstein(M, distance_matrix[0], distance_matrix[1], alpha=alpha)
    accs.append(accuracy.accuracy(G))

# %%
plt.plot(alphas,accs)
plt.xlabel("alpha")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
lcp = utils.LoadCloudPoint(filepath="datasets/csv_files/0005_Jogging001.csv")

# %%
timestep = 50
source_pc, target_pc = lcp.get_pointclouds_fixed_timestep(timestep, fixed_beginning_idx=0)

dp = utils.DistanceProfile(source_pc, target_pc)
distance_matrix = dp.compute_L2_matrix()

# %%
M = ot.dist(source_pc, target_pc)
G = ot.fused_gromov_wasserstein(M, distance_matrix[0], distance_matrix[1])

# %%
accs = []
timestep_step = 20
num_timesteps = 50
alpha_step = 0.05
alphas = np.arange(0, 1 + alpha_step, alpha_step)
timesteps = np.arange(1, num_timesteps*timestep_step+1, timestep_step)
for timestep in timesteps:
    for alpha in alphas:
        source_pc, target_pc = lcp.get_pointclouds_fixed_timestep(timestep, fixed_beginning_idx=0)
        dp = utils.DistanceProfile(source_pc, target_pc)
        distance_matrix = dp.compute_L2_matrix()
        M = ot.dist(source_pc, target_pc)
        G = ot.fused_gromov_wasserstein(M, distance_matrix[0], distance_matrix[1], alpha=alpha)
        accs.append(accuracy.accuracy(G))

# %%
accs_stacked = np.array(accs).reshape(50, -1)

# %%
counter = 1
for acc_arr in accs_stacked:
    plt.plot(alphas, acc_arr, alpha = counter / accs_stacked.shape[0], c = "black")
    counter += 1

# %%
source_pc, target_pc = lcp.get_pointclouds_fixed_timestep(5, fixed_beginning_idx=0)
dp = utils.DistanceProfile(source_pc, target_pc)
distance_matrix = dp.compute_L2_matrix()
M = ot.dist(source_pc, target_pc)
G = ot.fused_gromov_wasserstein(M, distance_matrix[0], distance_matrix[1], alpha=0)
utils.plot_3d_points_and_connections(source_pc, target_pc, G)

# %%
G = ot.solve(ot.dist(source_pc, target_pc), np.ones(source_pc.shape[0])/ (source_pc.shape[0]), np.ones(target_pc.shape[0]) / target_pc.shape[0]).plan

# %%
np.mean(np.linalg.norm((np.linalg.inv(np.diag(np.sum(G, axis = 1))) @ G) @ target_pc - target_pc, axis = 1))
# Out:
# np.float64(212.07358122426143)

# %%
dist_accs = []
timestep_step = 1
num_timesteps = 300
alpha_step = 0.1
alphas = np.arange(0, 1 + alpha_step, alpha_step)
timesteps = np.arange(1, num_timesteps*timestep_step+1, timestep_step)
for timestep in timesteps:
    for alpha in alphas:
        source_pc, target_pc = lcp.get_pointclouds_fixed_timestep(timestep, fixed_beginning_idx=0)
        dp = utils.DistanceProfile(source_pc, target_pc)
        distance_matrix = dp.compute_L2_matrix()
        M = ot.dist(source_pc, target_pc)
        G = ot.fused_gromov_wasserstein(M, distance_matrix[0], distance_matrix[1], alpha=alpha)
        dist_accs.append(accuracy.dist_accuracy(source_pc, target_pc, G))
    print(f"finished timestep {timestep}")
# Out:
# finished timestep 1
# finished timestep 2
# finished timestep 3
# finished timestep 4
# finished timestep 5
# finished timestep 6
# finished timestep 7
# finished timestep 8
# finished timestep 9
# finished timestep 10
# finished timestep 11
# finished timestep 12
# finished timestep 13
# finished timestep 14
# finished timestep 15
# finished timestep 16
# finished timestep 17
# finished timestep 18
# finished timestep 19
# finished timestep 20
# finished timestep 21
# finished timestep 22
# finished timestep 23
# finished timestep 24
# finished timestep 25
# finished timestep 26
# finished timestep 27
# finished timestep 28
# finished timestep 29
# finished timestep 30
# finished timestep 31
# finished timestep 32
# finished timestep 33
# finished timestep 34
# finished timestep 35
# finished timestep 36
# finished timestep 37
# finished timestep 38
# finished timestep 39
# finished timestep 40
# finished timestep 41
# finished timestep 42
# finished timestep 43
# finished timestep 44
# finished timestep 45
# finished timestep 46
# finished timestep 47
# finished timestep 48
# finished timestep 49
# finished timestep 50
# finished timestep 51
# finished timestep 52
# finished timestep 53
# finished timestep 54
# finished timestep 55
# finished timestep 56
# finished timestep 57
# finished timestep 58
# finished timestep 59
# finished timestep 60
# finished timestep 61
# finished timestep 62
# finished timestep 63
# finished timestep 64
# finished timestep 65
# finished timestep 66
# finished timestep 67
# finished timestep 68
# finished timestep 69
# finished timestep 70
# finished timestep 71
# finished timestep 72
# finished timestep 73
# finished timestep 74
# finished timestep 75
# finished timestep 76
# finished timestep 77
# finished timestep 78
# finished timestep 79
# finished timestep 80
# finished timestep 81
# finished timestep 82
# finished timestep 83
# finished timestep 84
# finished timestep 85
# finished timestep 86
# finished timestep 87
# finished timestep 88
# finished timestep 89
# finished timestep 90
# finished timestep 91
# finished timestep 92
# finished timestep 93
# finished timestep 94
# finished timestep 95
# finished timestep 96
# finished timestep 97
# finished timestep 98
# finished timestep 99
# finished timestep 100
# finished timestep 101
# finished timestep 102
# finished timestep 103
# finished timestep 104
# finished timestep 105
# finished timestep 106
# finished timestep 107
# finished timestep 108
# finished timestep 109
# finished timestep 110
# finished timestep 111
# finished timestep 112
# finished timestep 113
# finished timestep 114
# finished timestep 115
# finished timestep 116
# finished timestep 117
# finished timestep 118
# finished timestep 119
# finished timestep 120
# finished timestep 121
# finished timestep 122
# finished timestep 123
# finished timestep 124
# finished timestep 125
# finished timestep 126
# finished timestep 127
# finished timestep 128
# finished timestep 129
# finished timestep 130
# finished timestep 131
# finished timestep 132
# finished timestep 133
# finished timestep 134
# finished timestep 135
# finished timestep 136
# finished timestep 137
# finished timestep 138
# finished timestep 139
# finished timestep 140
# finished timestep 141
# finished timestep 142
# finished timestep 143
# finished timestep 144
# finished timestep 145
# finished timestep 146
# finished timestep 147
# finished timestep 148
# finished timestep 149
# finished timestep 150
# finished timestep 151
# finished timestep 152
# finished timestep 153
# finished timestep 154
# finished timestep 155
# finished timestep 156
# finished timestep 157
# finished timestep 158
# finished timestep 159
# finished timestep 160
# finished timestep 161
# finished timestep 162
# finished timestep 163
# finished timestep 164
# finished timestep 165
# finished timestep 166
# finished timestep 167
# finished timestep 168
# finished timestep 169
# finished timestep 170
# finished timestep 171
# finished timestep 172
# finished timestep 173
# finished timestep 174
# finished timestep 175
# finished timestep 176
# finished timestep 177
# finished timestep 178
# finished timestep 179
# finished timestep 180
# finished timestep 181
# finished timestep 182
# finished timestep 183
# finished timestep 184
# finished timestep 185
# finished timestep 186
# finished timestep 187
# finished timestep 188
# finished timestep 189
# finished timestep 190
# finished timestep 191
# finished timestep 192
# finished timestep 193
# finished timestep 194
# finished timestep 195
# finished timestep 196
# finished timestep 197
# finished timestep 198
# finished timestep 199
# finished timestep 200
# finished timestep 201
# finished timestep 202
# finished timestep 203
# finished timestep 204
# finished timestep 205
# finished timestep 206
# finished timestep 207
# finished timestep 208
# finished timestep 209
# finished timestep 210
# finished timestep 211
# finished timestep 212
# finished timestep 213
# finished timestep 214
# finished timestep 215
# finished timestep 216
# finished timestep 217
# finished timestep 218
# finished timestep 219
# finished timestep 220
# finished timestep 221
# finished timestep 222
# finished timestep 223
# finished timestep 224
# finished timestep 225
# finished timestep 226
# finished timestep 227
# finished timestep 228
# finished timestep 229
# finished timestep 230
# finished timestep 231
# finished timestep 232
# finished timestep 233
# finished timestep 234
# finished timestep 235
# finished timestep 236
# finished timestep 237
# finished timestep 238
# finished timestep 239
# finished timestep 240
# finished timestep 241
# finished timestep 242
# finished timestep 243
# finished timestep 244
# finished timestep 245
# finished timestep 246
# finished timestep 247
# finished timestep 248
# finished timestep 249
# finished timestep 250
# finished timestep 251
# finished timestep 252
# finished timestep 253
# finished timestep 254
# finished timestep 255
# finished timestep 256
# finished timestep 257
# finished timestep 258
# finished timestep 259
# finished timestep 260
# finished timestep 261
# finished timestep 262
# finished timestep 263
# finished timestep 264
# finished timestep 265
# finished timestep 266
# finished timestep 267
# finished timestep 268
# finished timestep 269
# finished timestep 270
# finished timestep 271
# finished timestep 272
# finished timestep 273
# finished timestep 274
# finished timestep 275
# finished timestep 276
# finished timestep 277
# finished timestep 278
# finished timestep 279
# finished timestep 280
# finished timestep 281
# finished timestep 282
# finished timestep 283
# finished timestep 284
# finished timestep 285
# finished timestep 286
# finished timestep 287
# finished timestep 288
# finished timestep 289
# finished timestep 290
# finished timestep 291
# finished timestep 292
# finished timestep 293
# finished timestep 294
# finished timestep 295
# finished timestep 296
# finished timestep 297
# finished timestep 298
# finished timestep 299
# finished timestep 300

# %%
dist_accs_stacked = np.array(dist_accs).reshape(num_timesteps, -1)

# %%
counter = 1
for acc_arr in dist_accs_stacked:
    plt.plot(alphas, acc_arr, alpha = counter / dist_accs_stacked.shape[0], c = "black")
    counter += 1

# %%
plt.scatter(timesteps, [alphas[x.argmin()] for x in dist_accs_stacked])
plt.xlabel("number of timesteps in the future")
plt.ylabel("best alpha value by distance accuracy")
plt.title("Regular Wasserstein (alpha = 0) vs. Gromow Wasserstein (alpha =1 )")
# Out:
# Text(0.5, 1.0, 'Regular Wasserstein (alpha = 0) vs. Gromow Wasserstein (alpha =1 )')

# %%
# Out:
# array([ 1.623648e+03,  2.562207e+03, -5.436400e+01,  1.561032e+03,
#         2.728980e+03, -4.018900e+01,  1.562895e+03,  2.633810e+03,
#         1.617750e+02,  1.184764e+03,  2.692918e+03,  1.457500e+01,
#         1.133353e+03,  2.568540e+03,  2.951000e+00,  1.323044e+03,
#         2.417342e+03,  1.149490e+02,  1.028551e+03,  2.476519e+03,
#         1.358580e+02,  8.803920e+02,  2.595647e+03, -5.019200e+01,
#         9.364400e+02,  2.618741e+03, -1.141010e+02,  8.316540e+02,
#         2.813456e+03,  9.013500e+01,  1.348063e+03,  2.848627e+03,
#         3.086840e+02,  1.139020e+03,  2.820724e+03,  3.639830e+02,
#         9.135220e+02,  2.927936e+03,  2.372370e+02,  1.016574e+03,
#         2.958958e+03,  2.314600e+02,  8.445260e+02,  0.000000e+00,
#         0.000000e+00,  9.603240e+02,  2.569050e+03,  2.079400e+02,
#         9.825230e+02,  2.669591e+03,  2.442780e+02,  9.952800e+02,
#         2.596972e+03,  7.848600e+01,  4.460320e+02,  2.707448e+03,
#         1.887650e+02,  3.519120e+02,  2.598011e+03,  4.083110e+02,
#         1.232230e+02,  2.630286e+03,  3.172810e+02,  4.215800e+01,
#         2.697756e+03,  2.816030e+02,  6.381260e+02,  2.884357e+03,
#         5.657400e+01,  4.624290e+02,  2.878136e+03,  1.084650e+02,
#         1.441020e+02,  2.791715e+03,  2.970470e+02,  8.072400e+01,
#         2.850494e+03,  1.021850e+02])
